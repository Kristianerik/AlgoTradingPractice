# %% [markdown]
# Installing Dependencies

# %%
# %pip install yfinance
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Downloading and Loading Data into DF

# %%
Apple = yf.download("AAPL", start='2010-01-01', end='2021-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.478998
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.490201
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.386964
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.375157
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.417540
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  129.679764
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.317856
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  132.529404
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.399353
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  130.387238
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
ticker = ["SPY","AAPL","KO"]

# %%
stocks = yf.download(ticker, start='2010-01-01', end='2021-01-01')
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478998  18.498014   87.129929    7.643214  28.520000
# 2010-01-05    6.490201  18.274252   87.360558    7.656429  28.174999
# 2010-01-06    6.386964  18.267769   87.422096    7.534643  28.165001
# 2010-01-07    6.375157  18.222364   87.791138    7.520714  28.094999
# 2010-01-08    6.417540  17.885092   88.083290    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679764  48.779110  352.967987  131.970001  53.439999
# 2020-12-28  134.317856  49.436310  356.000336  136.690002  54.160000
# 2020-12-29  132.529404  49.408924  355.321106  134.869995  54.130001
# 2020-12-30  131.399353  49.691898  355.828156  133.720001  54.439999
# 2020-12-31  130.387238  50.057003  357.636017  132.690002  54.840000
#
# ...

# %%
stocks.to_csv("stocksT.csv")

# %%
stocks = pd.read_csv("stocksT.csv")

# %%
stocks
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0            NaN                AAPL                  KO                 SPY
# 1           Date                 NaN                 NaN                 NaN
# 2     2010-01-04   6.478998184204102  18.498014450073242   87.12992858886719
# 3     2010-01-05   6.490200996398926   18.27425193786621   87.36055755615234
# 4     2010-01-06   6.386963844299316   18.26776885986328    87.4220962524414
# ...          ...                 ...                 ...                 ...
# 2766  2020-12-24   129.6797637939453  48.779109954833984   352.9679870605469
# 2767  2020-12-28  134.31785583496094  49.436309814453125   356.0003356933594
# 2768  2020-12-29  132.52940368652344    49.4089241027832  355.32110595703125
# 2769  2020-12-30  131.39935302734375  49.691898345947266   355.8281555175781
# 2770  2020-12-31  130.38723754882812  50.057003021240234   357.6360168457031
#
# ...

# %%
stocks = pd.read_csv("stocksT.csv", header=[0,1])
stocks
# Out:
#      Unnamed: 0_level_0   Adj Close                              Close  \
#      Unnamed: 0_level_1        AAPL         KO         SPY        AAPL
# 0                  Date         NaN        NaN         NaN         NaN
# 1            2010-01-04    6.478998  18.498014   87.129929    7.643214
# 2            2010-01-05    6.490201  18.274252   87.360558    7.656429
# 3            2010-01-06    6.386964  18.267769   87.422096    7.534643
# 4            2010-01-07    6.375157  18.222364   87.791138    7.520714
# ...                 ...         ...        ...         ...         ...
# 2765         2020-12-24  129.679764  48.779110  352.967987  131.970001
# 2766         2020-12-28  134.317856  49.436310  356.000336  136.690002
# 2767         2020-12-29  132.529404  49.408924  355.321106  134.869995
# 2768         2020-12-30  131.399353  49.691898  355.828156  133.720001
# 2769         2020-12-31  130.387238  50.057003  357.636017  132.690002
#
# ...

# %%
stocks = pd.read_csv("stocksT.csv", header=[0,1], index_col=[0])
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478998  18.498014   87.129929    7.643214  28.520000
# 2010-01-05    6.490201  18.274252   87.360558    7.656429  28.174999
# 2010-01-06    6.386964  18.267769   87.422096    7.534643  28.165001
# 2010-01-07    6.375157  18.222364   87.791138    7.520714  28.094999
# 2010-01-08    6.417540  17.885092   88.083290    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679764  48.779110  352.967987  131.970001  53.439999
# 2020-12-28  134.317856  49.436310  356.000336  136.690002  54.160000
# 2020-12-29  132.529404  49.408924  355.321106  134.869995  54.130001
# 2020-12-30  131.399353  49.691898  355.828156  133.720001  54.439999
# 2020-12-31  130.387238  50.057003  357.636017  132.690002  54.840000
#
# ...

# %%
stocks = pd.read_csv("stocksT.csv", header=[0,1], index_col=[0], parse_dates=[0])
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478998  18.498014   87.129929    7.643214  28.520000
# 2010-01-05    6.490201  18.274252   87.360558    7.656429  28.174999
# 2010-01-06    6.386964  18.267769   87.422096    7.534643  28.165001
# 2010-01-07    6.375157  18.222364   87.791138    7.520714  28.094999
# 2010-01-08    6.417540  17.885092   88.083290    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679764  48.779110  352.967987  131.970001  53.439999
# 2020-12-28  134.317856  49.436310  356.000336  136.690002  54.160000
# 2020-12-29  132.529404  49.408924  355.321106  134.869995  54.130001
# 2020-12-30  131.399353  49.691898  355.828156  133.720001  54.439999
# 2020-12-31  130.387238  50.057003  357.636017  132.690002  54.840000
#
# ...

# %%
stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %% [markdown]
# Data Visualization

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.478998        18.498014         87.129929
# 2010-01-05           6.490201        18.274252         87.360558
# 2010-01-06           6.386964        18.267769         87.422096
# 2010-01-07           6.375157        18.222364         87.791138
# 2010-01-08           6.417540        17.885092         88.083290
# ...                       ...              ...               ...
# 2020-12-24         129.679764        48.779110        352.967987
# 2020-12-28         134.317856        49.436310        356.000336
# 2020-12-29         132.529404        49.408924        355.321106
# 2020-12-30         131.399353        49.691898        355.828156
# 2020-12-31         130.387238        50.057003        357.636017
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478998  18.498014   87.129929    7.643214  28.520000
# 2010-01-05    6.490201  18.274252   87.360558    7.656429  28.174999
# 2010-01-06    6.386964  18.267769   87.422096    7.534643  28.165001
# 2010-01-07    6.375157  18.222364   87.791138    7.520714  28.094999
# 2010-01-08    6.417540  17.885092   88.083290    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679764  48.779110  352.967987  131.970001  53.439999
# 2020-12-28  134.317856  49.436310  356.000336  136.690002  54.160000
# 2020-12-29  132.529404  49.408924  355.321106  134.869995  54.130001
# 2020-12-30  131.399353  49.691898  355.828156  133.720001  54.439999
# 2020-12-31  130.387238  50.057003  357.636017  132.690002  54.840000
#
# ...

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     31.562566    32.208758   182.052367    33.777537    41.320121
# std      24.614793     8.183724    69.703574    24.572747     6.808527
# min       5.814177    16.373821    79.271965     6.858929    25.014999
# 25%      15.201319    26.605541   114.881248    17.484285    37.660000
# 50%      24.549244    31.768909   175.981079    26.987499    41.759998
# 75%      40.931641    37.628502   241.932739    43.007500    45.549999
# max     134.317856    53.069550   357.636017   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# ...

# %%
close = stocks.loc[:,"Close"].copy()
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
plt.style.use("dark_background")

# %%
close.plot(figsize=[15,8], fontsize=12, title="Closing Prices Over Time")
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2020-12-24    1726.629626
# 2020-12-28    1788.383766
# 2020-12-29    1764.571699
# 2020-12-30    1749.525753
# 2020-12-31    1736.049763
# Name: AAPL, Length: 2769, dtype: float64

# %%
normClose = close.div(close.iloc[0]).mul(100)

# %%
normClose.plot(figsize=[15,8], fontsize=12, title="Closing Prices Over Time")
plt.legend(fontsize=12)
plt.show()

# %%
aapl = close.AAPL.copy().to_frame()

# %% [markdown]
# Data Manipulation

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods=1)
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
aapl["Diff"]=aapl.AAPL.sub(aapl.lag1)
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  1.009995
# 2020-12-28  136.690002  131.970001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999
#
# [2769 rows x 3 columns]

# %%
aapl["% Change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995    0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001    3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007   -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994   -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999   -0.770265
#
# [2769 rows x 6 columns]

# %%
aapl["Diff2"] = aapl.AAPL.diff(periods=1)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995    0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001    3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007   -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994   -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999   -0.770265
#
# [2769 rows x 6 columns]

# %%
aapl["% Change 2"] = aapl.AAPL.pct_change(periods=1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712  1.009995    0.771224
# 2020-12-28  136.690002  131.970001  4.720001  1.035766  4.720001    3.576571
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685 -1.820007   -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473 -1.149994   -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297 -1.029999   -0.770265
#
# [2769 rows x 6 columns]

# %%
del aapl["% Change 2"]

# %%
aapl
# Out:
#                   AAPL  % Change
# Date
# 2010-01-04    7.643214       NaN
# 2010-01-05    7.656429  0.172893
# 2010-01-06    7.534643 -1.590632
# 2010-01-07    7.520714 -0.184871
# 2010-01-08    7.570714  0.664833
# ...                ...       ...
# 2020-12-24  131.970001  0.771224
# 2020-12-28  136.690002  3.576571
# 2020-12-29  134.869995 -1.331485
# 2020-12-30  133.720001 -0.852668
# 2020-12-31  132.690002 -0.770265
#
# [2769 rows x 2 columns]

# %%
aapl.rename(columns={"% Change": "Change"}, inplace=True)

# %%
aapl
# Out:
#                   AAPL    Change
# Date
# 2010-01-04    7.643214       NaN
# 2010-01-05    7.656429  0.172893
# 2010-01-06    7.534643 -1.590632
# 2010-01-07    7.520714 -0.184871
# 2010-01-08    7.570714  0.664833
# ...                ...       ...
# 2020-12-24  131.970001  0.771224
# 2020-12-28  136.690002  3.576571
# 2020-12-29  134.869995 -1.331485
# 2020-12-30  133.720001 -0.852668
# 2020-12-31  132.690002 -0.770265
#
# [2769 rows x 2 columns]

# %%
aapl.AAPL.resample("M").last()
# Out:
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-31    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: M, Name: AAPL, Length: 132, dtype: float64

# %%
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BM, Name: AAPL, Length: 132, dtype: float64

# %%
#del aapl["Change"]
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2768 entries, 2010-01-05 to 2020-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2768 non-null   float64
# dtypes: float64(1)
# memory usage: 43.2 KB

# %%
ret.plot(kind="hist",figsize=(12,8), bins=100)
plt.show()

# %%
daily_mean_return = ret.mean()
daily_mean_return
# Out:
# AAPL    0.001191
# dtype: float64

# %%
var_daily = ret.var()
var_daily
# Out:
# AAPL    0.000318
# dtype: float64

# %%
std_daily = np.sqrt(var_daily)
std_daily
# Out:
# AAPL    0.017843
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.017843
# dtype: float64

# %%
annual_mean_return = daily_mean_return * 252
annual_mean_return
# Out:
# AAPL    0.300134
# dtype: float64

# %%
annual_var_return = var_daily * 252
annual_var_return
# Out:
# AAPL    0.080226
# dtype: float64

# %%
annual_std_return = np.sqrt(annual_var_return)
annual_std_return
# Out:
# AAPL    0.283242
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# AAPL    0.283242
# dtype: float64

# %%
ticker=["SPY","AAPL","KO","IBM","DIS","MSFT"]

# %%
stocks = yf.download(ticker, start = '2010-01-01', end = '2021-01-01')
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
close=stocks.loc[:,"Close"].copy()

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397

# %%
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  2768.0  0.001191  0.017843 -0.128647 -0.007123  0.000903  0.010379
# DIS   2768.0  0.000749  0.015717 -0.129846 -0.006210  0.000629  0.007901
# IBM   2768.0  0.000082  0.014132 -0.128507 -0.006321  0.000287  0.006743
# KO    2768.0  0.000298  0.011088 -0.096725 -0.004698  0.000438  0.005706
# MSFT  2768.0  0.000841  0.016012 -0.147390 -0.006939  0.000654  0.008636
# SPY   2768.0  0.000491  0.010909 -0.109424 -0.003532  0.000637  0.005421
#
#            max
# AAPL  0.119808
# DIS   0.144123
# IBM   0.113010
# KO    0.064796
# MSFT  0.142169
# SPY   0.090603

# %%
summary = ret.describe().T.loc[:,['mean','std']]
summary
# Out:
#           mean       std
# AAPL  0.001191  0.017843
# DIS   0.000749  0.015717
# IBM   0.000082  0.014132
# KO    0.000298  0.011088
# MSFT  0.000841  0.016012
# SPY   0.000491  0.010909

# %%
summary['mean'] = summary['mean']*252
summary['std'] = summary['std']*np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.300134  0.283242
# DIS   0.188696  0.249504
# IBM   0.020648  0.224345
# KO    0.075091  0.176009
# MSFT  0.211915  0.254185
# SPY   0.123754  0.173170
